# %%
! pip install sentence-transformers
# Out:
# ...
#      ---------------------------------------- 0.0/44.0 kB ? eta -:--:--
#      ----------------------------------- -- 41.0/44.0 kB 991.0 kB/s eta 0:00:01
#      ---------------------------------------- 44.0/44.0 kB 1.1 MB/s eta 0:00:00
# ...
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# ...
#    ---------------------------------------- 0.0/488.0 kB ? eta -:--:--
#    ------------------------------ --------- 368.6/488.0 kB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 488.0/488.0 kB 7.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.0 MB 14.2 MB/s eta 0:00:01
#    --- ------------------------------------ 1.0/12.0 MB 12.2 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.6/12.0 MB 12.7 MB/s eta 0:00:01
#    ------- -------------------------------- 2.2/12.0 MB 11.8 MB/s eta 0:00:01
# ...

# %%
import os, json
from pathlib import Path
from typing import List, Dict, Tuple, Optional

import numpy as np
import pandas as pd

import torch
from sentence_transformers import SentenceTransformer

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# ---- Paths & Model ----
INPUT_CSV = "civil_val.csv"   # <-- your file
ARTIFACT_DIR = Path("./tone_artifacts")
ARTIFACT_DIR.mkdir(parents=True, exist_ok=True)

MODEL_NAME = "sentence-transformers/all-MiniLM-L6-v2"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
BATCH_SIZE = 64
TEST_SIZE = 0.30
RANDOM_STATE = 42

# Auto-detect column names
TEXT_COL_CANDIDATES  = ["text","comment_text","comment","content","body","message"]
LABEL_COL_CANDIDATES = ["tone_label","label","sentiment"]  # expects {positive, neutral, negative}
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\shiva\anaconda3\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py:73
#      72 try:
# ---> 73   from tensorflow.python._pywrap_tensorflow_internal import *
#      74 # This try catch logic is because there is no bazel equivalent for py_extension.
#      75 # Externally in opensource we must enable exceptions to load the shared object
#      76 # by exposing the PyInit symbols with pybind. This error will only be
#      77 # caught internally or if someone changes the name of the target _pywrap_tensorflow_internal.
#      78
#      79 # This logic is used in other internal projects using py_extension.
#
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
# During handling of the above exception, another exception occurred:
#
# ...
